# %% [markdown]
# <style type="text/css">
#     :root {
#         --jp-notebook-padding: 0px !important;
#         --jp-cell-padding: 0px !important;
#         --jp-cell-prompt-width: 0px !important;
#     }
#
#     @page {
#         size: A4 portrait !important;
#         margin: 5mm 5mm 5mm 5mm !important;
#     }
#
#     html,
#     body,
#     body.jp-Notebook,
#     main {
#         margin: 0px !important;
#         padding: 0px !important;
#         max-width: none !important;
#         width: 100% !important;
#     }
#
#     .jp-Notebook,
#     .jp-Notebook-cell,
#     .jp-Cell,
#     .jp-Cell-inputWrapper,
#     .jp-Cell-outputWrapper,
#     .jp-InputArea,
#     .jp-OutputArea,
#     .jp-RenderedHTMLCommon,
#     .jp-MarkdownOutput,
#     .jp-InputArea-editor,
#     .jp-CodeMirrorEditor,
#     .jp-OutputArea-output {
#         margin-left: 0px !important;
#         margin-right: 0px !important;
#         padding-left: 0px !important;
#         padding-right: 0px !important;
#         max-width: none !important;
#         width: 100% !important;
#         box-sizing: border-box !important;
#     }
#
#     .jp-InputPrompt,
#     .jp-OutputPrompt,
#     .jp-Collapser {
#         display: none !important;
#         width: 0px !important;
#         min-width: 0px !important;
#         flex: 0 0 0px !important;
#         padding: 0px !important;
#         margin: 0px !important;
#     }
#
#     pre,
#     pre > *,
#     .jp-RenderedHTMLCommon pre,
#     .jp-InputArea-editor pre,
#     .jp-CodeMirrorEditor pre {
#         line-height: 125% !important;
#         white-space: pre-wrap !important;
#         word-break: break-word !important;
#         overflow-wrap: anywhere !important;
#     }
#
#     .jp-RenderedHTMLCommon > pre {
#         margin-left: 0px !important;
#         margin-right: 0px !important;
#     }
#
#     .jp-RenderedHTMLCommon table {
#         width: 100% !important;
#         table-layout: auto !important;
#     }
#
#     .jp-RenderedHTMLCommon img {
#         max-width: 100% !important;
#         height: auto !important;
#     }
# </style>

# %% [markdown]
# # Kapitel 4: Algorithmische Grundstrukturen und ihre Darstellung
#
# Bisher haben wir ausschließlich Programme gesehen, bei denen der Programmcode Zeile für Zeile nacheinander ausgewertet wird.
#
# Mithilfe **algorithmischer Grundstrukturen** können wir von diesem Verhalten abweichen.
#
# **Algorithmische Grundstrukturen steuern dabei den Ablauf eines Programms.** Mit ihnen könnt ihr Anweisungsblöcke definieren, die nur unter einer bestimmten Bedingung ausgeführt werden, oder auch solche, deren Ausführung mehrfach erfolgt. Hierfür unterscheiden wir **Sequenzen**, **Verzweigungen** und **Schleifen**, die wir uns - inklusive dreier **Darstellungsformen** - nachfolgend genauer anschauen.

# %% [markdown]
# ## 4.1. Darstellungsformen
#
# Programme und Algorithmen können auf verschiedene Art und Weise dargestellt werden. Zu nennen sind hierbei die Darstellungsformen __Pseudocode__, __Code__ und __Struktogramm__.
#
# Der __Pseudocode__ ist eine natürlichsprachliche Formulierung des Programms. Er versucht, in einfacher und nachvollziehbarer Sprache die Struktur eines Programms wiederzugeben. Ihr beschreibt also umgangssprachlich, was passieren soll, zum Beispiel "eine Zahl eingeben" oder "das Ergebnis ausgeben".
#
# Der __Code__ ist natürlich abhängig von der gewählten Programmiersprache. Wir werden hierbei ausschließlich Python-Code nutzen.
#
# Das __Struktogramm (auch: Nassi-Shneiderman-Diagramm)__ versucht, mithilfe einfacher geometrischer Formen den Programmablauf zu visualisieren und strukturiert darzustellen. Ein digitales Tool zur Erstellung von Struktogrammen steht euch unter [🛜 Struktog.](https://binkert-patrick.de/struktog/) zur Verfügung.
#
# Diese Darstellungsformen werden nachfolgend bei den algorithmischen Grundstrukturen mit Beispielen veranschaulicht.
#
# Zu den Struktogrammen sei erwähnt, dass die verwendeten Farben **nicht** vorgeschrieben sind, sondern lediglich durch das verwendete Tool entstehen.

# %% [markdown]
# <p style="page-break-after:always;"></p>
#
# ## 4.2. Sequenz
#
# Bei der **Sequenz** handelt es sich schlichtweg um eine **Abfolge von Anweisungen**.
#
# Diese werden nacheinander aufgeschrieben und von oben nach unten abgearbeitet.
#
# Alle bisher verwendeten Codeschnipsel waren demnach Sequenzen.
#
# Visualisieren wir dies an einem einfachen **Beispiel**:
# Dabei wird eine Zahl eingegeben, das Quadrat dieser Zahl berechnet und die berechnete Quadratzahl ausgegeben.

# %%
eingabe = input("Gib eine Zahl ein: ")
zahl = int(eingabe)
quadrat_zahl = zahl**2
print(quadrat_zahl)

# %% [markdown]
# Eine Darstellung des Codes in **Pseudocode** wäre:
#
#     Zahl eingeben
#     Quadrat der Zahl berechnen
#     Quadratzahl ausgeben

# %% [markdown]
# In einem **Struktogramm** wird jede Anweisung in einem **Rechteck** dargestellt.
#
# Eingaben werden dabei mit einem vorangestellten ```E``` und Ausgaben mit einem vorangestellten ```A``` gekennzeichnet.
#
# Damit ergibt sich die folgende Darstellung:
#
# ![Struktogramm](C4_01_sequenz.png)

# %% [markdown]
# Das Beispiel zeigt direkt, dass die Darstellungsformen **Pseudocode** und **Struktogramm** nicht immer zu 100% zu unserer Programmiersprache passen.
#
# Im obigen Code sehen wir die folgende Zeile.

# %%
zahl = int(eingabe)

# %% [markdown]
# Diese Zeile wird in den anderen Darstellungsformen **nicht** berücksichtigt. Aber wir wissen, dass jede Nutzereingabe zunächst vom Datentyp ```str``` ist. Wenn wir damit rechnen wollen, **müssen** wir den Datentyp also in eine ganze Zahl oder Dezimalzahl umwandeln.

# %% [markdown]
# <p style="page-break-after:always;"></p>
#
# ## 4.3. Übungen zur Sequenz
#
# ### Aufgabe 1
# Implementiere den folgenden Pseudocode. Teste das Programm!
#
# ```
# ganze Zahl a eingeben
# ganze Zahl b eingeben
# Summe beider Zahlen berechnen
# Summe ausgeben
# ```

# %%
# MUSTERLÖSUNG! Es gibt nicht nur eine richtige Lösung, das ist lediglich ein Beispiel, wie man die Aufgabe lösen könnte.

a = input("Gib eine Zahl a ein: ")
a = int(a)

b = input("Gib eine Zahl b ein: ")
b = int(b)

summe = a + b

print(f"Die Summe von {a} und {b} ist {summe}.")
# Out:
# Die Summe von 5 und 3 ist 8.

# %% [markdown]
# <p style="page-break-after:always;"></p>
#
# ### Aufgabe 2
# Implementiere das folgende Struktogramm. Achte bei der Ausgabe auf das **exakte Setzen** der Leerzeichen!
#
# ![Struktogramm](C4_01_uebung_zur_sequenz.png)

# %%
# MUSTERLÖSUNG! Es gibt nicht nur eine richtige Lösung, das ist lediglich ein Beispiel, wie man die Aufgabe lösen könnte.

zeit = input("Gib die Zeit in Sekunden ein: ")
zeit = int(zeit)

minuten = zeit // 60
sekunden = zeit % 60

print(f'{zeit} Sekunden entsprechen {minuten} Minuten und {sekunden} Sekunden.')
# Out:
# 123 Sekunden entsprechen 2 Minuten und 3 Sekunden.

# %% [markdown]
# <p style="page-break-after:always;"></p>
#
# ### Aufgabe 3
# Implementiere den folgenden Pseudocode. Teste das Programm anschließend mit verschiedenen Eingaben!
#
# ```
# Name eingeben
# Alter eingeben
# Alter in zehn Jahren berechnen
# vollständigen Satz mit Namen, aktuellem Alter und Alter in zehn Jahren ausgeben
# ```
#
# Denke daran, dass Eingaben mit `input()` zunächst als Text gespeichert werden.

# %%
# MUSTERLÖSUNG! Es gibt nicht nur eine richtige Lösung, das ist lediglich ein Beispiel, wie man die Aufgabe lösen könnte.

name = input('Gib deinen Namen ein: ')

alter = input('Gib dein Alter ein: ')
alter = int(alter)

alter_in_10_jahren = alter + 10

print(f'Hallo {name} du bist aktuell {alter} Jahre alt und in 10 Jahren wirst du {alter_in_10_jahren} Jahre alt sein.')
# Out:
# Hallo Patrick du bist aktuell 28 Jahre alt und in 10 Jahren wirst du 38 Jahre alt sein.

# %% [markdown]
# <p style="page-break-after:always;"></p>
#
# <a href="https://learningview.org/app/#!/" title="Auf zu LearningView! :-)">![LearningView](00_learningview.png)</a>

# %% [markdown]
# <hr/>
#
# <div style="width:100%; text-align:center;">
# <p style="text-align:center; margin:0;">© Patrick Binkert & Dr. Stephan Matos Camacho | SJ 26 / 27</p>
# <br/>
# <img src="00_coding@BvC.png" alt="FooterImage" width="400" style="display:block; width:400px; max-width:100%; height:auto; margin:0 auto;"/>
# </div>
