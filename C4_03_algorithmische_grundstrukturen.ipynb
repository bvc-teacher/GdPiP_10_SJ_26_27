# %% [markdown]
# <style type="text/css">
#     :root {
#         --jp-notebook-padding: 0px !important;
#         --jp-cell-padding: 0px !important;
#         --jp-cell-prompt-width: 0px !important;
#     }
#
#     @page {
#         size: A4 portrait !important;
#         margin: 5mm 5mm 5mm 5mm !important;
#     }
#
#     html,
#     body,
#     body.jp-Notebook,
#     main {
#         margin: 0px !important;
#         padding: 0px !important;
#         max-width: none !important;
#         width: 100% !important;
#     }
#
#     .jp-Notebook,
#     .jp-Notebook-cell,
#     .jp-Cell,
#     .jp-Cell-inputWrapper,
#     .jp-Cell-outputWrapper,
#     .jp-InputArea,
#     .jp-OutputArea,
#     .jp-RenderedHTMLCommon,
#     .jp-MarkdownOutput,
#     .jp-InputArea-editor,
#     .jp-CodeMirrorEditor,
#     .jp-OutputArea-output {
#         margin-left: 0px !important;
#         margin-right: 0px !important;
#         padding-left: 0px !important;
#         padding-right: 0px !important;
#         max-width: none !important;
#         width: 100% !important;
#         box-sizing: border-box !important;
#     }
#
#     .jp-InputPrompt,
#     .jp-OutputPrompt,
#     .jp-Collapser {
#         display: none !important;
#         width: 0px !important;
#         min-width: 0px !important;
#         flex: 0 0 0px !important;
#         padding: 0px !important;
#         margin: 0px !important;
#     }
#
#     pre,
#     pre > *,
#     .jp-RenderedHTMLCommon pre,
#     .jp-InputArea-editor pre,
#     .jp-CodeMirrorEditor pre {
#         line-height: 125% !important;
#         white-space: pre-wrap !important;
#         word-break: break-word !important;
#         overflow-wrap: anywhere !important;
#     }
#
#     .jp-RenderedHTMLCommon > pre {
#         margin-left: 0px !important;
#         margin-right: 0px !important;
#     }
#
#     .jp-RenderedHTMLCommon table {
#         width: 100% !important;
#         table-layout: auto !important;
#     }
#
#     .jp-RenderedHTMLCommon img {
#         max-width: 100% !important;
#         height: auto !important;
#     }
# </style>

# %% [markdown]
# # Kapitel 4: Algorithmische Grundstrukturen und ihre Darstellung
#
# Bisher haben wir hauptsächlich Programme gesehen, bei denen der Programmcode Zeile für Zeile nacheinander ausgewertet wird. Mit Hilfe **algorithmischer Grundstrukturen** können wir diesem Verhalten abweichen.
#
# **Algorithmische Grundstrukturen steuern dabei den Ablauf eines Programms.** Mit ihnen könnt ihr Anweisungsblöcke definieren, die nur unter einer bestimmten Bedingung ausgeführt werden oder auch solche, deren Ausführung mehrfach erfolgt. Hierfür unterscheiden wir **Sequenzen**, **Verzweigungen** und **Schleifen**, welche wir uns - inklusiv dreier **Darstellungsformen** - nachfolgend genauer anschauen.

# %% [markdown]
# ## 4.6. Komplexe Bedingungen
#
# Manchmal genügt **nicht nur eine** einzige Bedingung.
#
# In machen Fällen reicht es uns, wenn eine von mehreren Bedingungen erfüllt ist oder es müssen mehrere Bedingungen gleichzeitig erfüllt sein.
#
# Zur Umsetzung dessen gibt es **logische Operatoren**.
#
# Wir unterscheiden das **logische UND (```&&``` bzw. in Python ```and```)** und das **logische ODER (```||``` bzw. in Python ```or```)**.

# %% [markdown]
# Beim **logischen UND** müssen beide Eingaben wahr sein, damit auch das Ergebnis der Verknüpfung wahr ist:
#
# Eingabe 1 | Eingabe 2 | Ausgabe
# :---: | :---: | :---:
# **```E1```** | **```E2```** | **```E1 && E2```**
# True | True | True
# True | False | False
# False | True | False
# False | False | False

# %% [markdown]
# <p style="page-break-after:always;"></p>
#
# Beim **logischen ODER** muss nur eine der beiden Eingaben wahr sein, damit das Ergebnis der Verknüpfung wahr ist:
#
# Eingabe 1 | Eingabe 2 | Ausgabe
# :---: | :---: | :---:
# **```E1```** | **```E2```** | **```E1 \|\| E2```**
# True | True | True
# True | False | True
# False | True | True
# False | False | False

# %% [markdown]
# **Das logische UND in Python:**

# %%
thema = 'Programmierung'
klasse = 10

# Beide Bedingungen müssen wahr (True) sein!
if thema == 'Programmierung' and klasse == 10: 
    print('It\'s a Match! 💞 Lovely!')
else:
    print('Bestimmt auch eine gute Kombination!')

# %% [markdown]
# **Das logische ODER in Python:**

# %%
zahl1 = 69
zahl2 = 42
zahl3 = 67
zahl4 = 187

# Nur eine der Bedingungen muss wahr (True) sein!
if zahl1 == 42 or zahl2 == 42 or zahl3 == 42 or zahl4 == 42: 
    print('Juhu! Die Zahl 42 ist am Start! 🚀')
else:
    print('Leider keine 42 dabei ...')

# %% [markdown]
# <p style="page-break-after:always;"></p>
#
# ## 4.7. Übungen zu komplexen Bedingungen

# %% [markdown]
# ### Aufgabe 1
# Gib jeweils an, welchen Wert der gegebene boolesche Ausdruck (für $ 𝑎 = 4 $ und $ 𝑏 = 1 $) hat.
#
# * ```(a < 5) || (a > 6)``` → ???
# * ```(a == 3) || (2 == b)``` → ???
# * ```(b > 1) && (a > 3)``` → ???
# * ```(a + b < 19) && (b < 1)``` → ???
# * ```(3 < 5) && (3 > 5)``` → ???

# %% [markdown]
# <p style="page-break-after:always;"></p>
#
# ### Aufgabe 2
# Implementiere ein Programm, welches in der Lage ist, nach der Eingabe der Seitenlängen der Seiten $a$, $b$ und $c$ zu entscheiden, ob ein Dreieck gleichschenklig ist.
#
# **Hinweis:** Ein Dreieck ist gleichschenklig, wenn die Seiten a und b **ODER** die Seiten b und c **ODER** die Seiten c und a gleich lang sind.

# %%
# HIER IST PLATZ FÜR EURE LÖSUNG! :)

# %% [markdown]
# <p style="page-break-after:always;"></p>
#
# ### Aufgabe 3
# Implementiere ein Programm, welches in der Lage ist, nach der Eingabe der Seitenlängen der Seiten $a$, $b$ und $c$ zu entscheiden, ob ein Dreieck rechtwinklig ist.
#
# **Hinweis:** Nutze den Satz des Pythagoras. Dabei kann jede beliebige Seite die Hypotenuse sein. Du musst also alle Möglichkeiten überprüfen.

# %%
# HIER IST PLATZ FÜR EURE LÖSUNG! :)

# %% [markdown]
# <p style="page-break-after:always;"></p>
#
# ### Aufgabe 4
# Implementiere ein Programm, welches in der Lage ist, nach der Eingabe des Alters und der Körpergröße zu entscheiden, ob eine Person mit einer Achterbahn fahren darf.
#
# **Regeln:** Eine Person darf mitfahren, wenn sie mindestens 12 Jahre alt **UND** mindestens 140 cm groß ist. Ab einem Alter von 16 Jahren genügt eine Körpergröße von mindestens 130 cm.

# %%
# HIER IST PLATZ FÜR EURE LÖSUNG! :)

# %% [markdown]
# <p style="page-break-after:always;"></p>
#
# ### Aufgabe 5
# Implementiere ein Programm, welches in der Lage ist, nach der Eingabe des Einkaufswertes zu entscheiden, ob eine Person einen Rabatt erhält.
#
# Zusätzlich soll abgefragt werden, ob die Person Schülerin oder Schüler ist und ob sie eine Kundenkarte besitzt.
#
# **Regeln:** Eine Person erhält Rabatt, wenn sie Schülerin oder Schüler ist **ODER** eine Kundenkarte besitzt. Zusätzlich muss der Einkaufswert mindestens 20 € betragen.

# %%
# HIER IST PLATZ FÜR EURE LÖSUNG! :)

# %% [markdown]
# <p style="page-break-after:always;"></p>
#
# <a href="https://learningview.org/app/#!/" title="Auf zu LearningView! :-)">![LearningView](00_learningview.png)</a>

# %% [markdown]
# <hr/>
#
# <div style="width:100%; text-align:center;">
# <p style="text-align:center; margin:0;">© Patrick Binkert & Dr. Stephan Matos Camacho | SJ 26 / 27</p>
# <br/>
# <img src="00_coding@BvC.png" alt="FooterImage" width="400" style="display:block; width:400px; max-width:100%; height:auto; margin:0 auto;"/>
# </div>
