# %% [markdown]
# <style type="text/css">
#     :root {
#         --jp-notebook-padding: 0px !important;
#         --jp-cell-padding: 0px !important;
#         --jp-cell-prompt-width: 0px !important;
#     }
#
#     @page {
#         size: A4 portrait !important;
#         margin: 5mm 5mm 5mm 5mm !important;
#     }
#
#     html,
#     body,
#     body.jp-Notebook,
#     main {
#         margin: 0px !important;
#         padding: 0px !important;
#         max-width: none !important;
#         width: 100% !important;
#     }
#
#     .jp-Notebook,
#     .jp-Notebook-cell,
#     .jp-Cell,
#     .jp-Cell-inputWrapper,
#     .jp-Cell-outputWrapper,
#     .jp-InputArea,
#     .jp-OutputArea,
#     .jp-RenderedHTMLCommon,
#     .jp-MarkdownOutput,
#     .jp-InputArea-editor,
#     .jp-CodeMirrorEditor,
#     .jp-OutputArea-output {
#         margin-left: 0px !important;
#         margin-right: 0px !important;
#         padding-left: 0px !important;
#         padding-right: 0px !important;
#         max-width: none !important;
#         width: 100% !important;
#         box-sizing: border-box !important;
#     }
#
#     .jp-InputPrompt,
#     .jp-OutputPrompt,
#     .jp-Collapser {
#         display: none !important;
#         width: 0px !important;
#         min-width: 0px !important;
#         flex: 0 0 0px !important;
#         padding: 0px !important;
#         margin: 0px !important;
#     }
#
#     pre,
#     pre > *,
#     .jp-RenderedHTMLCommon pre,
#     .jp-InputArea-editor pre,
#     .jp-CodeMirrorEditor pre {
#         line-height: 125% !important;
#         white-space: pre-wrap !important;
#         word-break: break-word !important;
#         overflow-wrap: anywhere !important;
#     }
#
#     .jp-RenderedHTMLCommon > pre {
#         margin-left: 0px !important;
#         margin-right: 0px !important;
#     }
#
#     .jp-RenderedHTMLCommon table {
#         width: 100% !important;
#         table-layout: auto !important;
#     }
#
#     .jp-RenderedHTMLCommon img {
#         max-width: 100% !important;
#         height: auto !important;
#     }
# </style>

# %% [markdown]
# # **Zusätzliche** und **freiwillige** Übungsaufgaben zur Vorbereitung auf die erste Leistungskontrolle
#
#
# <a href="https://learningview.org/app/#!/" title="Auf zu LearningView! :-)">![LearningView](00_learningview.png)</a>

# %% [markdown]
# ### Aufgabe 1 - Fehler identifizieren
#
# Jeder der folgenden Codeblöcke wird unabhängig voneinander betrachtet und ausgeführt.
#
# Erkläre jeweils die Fehlerursache in einem Kommentar direkt im Code.

# %%
text = "Willkommen im Informatikkurs!'

# %%
anzahl personen = 24

# %%
ergebnis = 3 * zahl

# %%
raum = "Raum " + 204

# %%
zahl = int("7.5")

# %% [markdown]
# <p style="page-break-after:always;"></p>
#
# ### Aufgabe 2 - Fehler korrigieren
#
# Jeder der folgenden Codeblöcke wird unabhängig voneinander betrachtet und ausgeführt.
#
# Korrigiere alle Fehler direkt im Code, sodass jeder Codeblock ausführbar ist und allen zuvor festgelegten Regeln entspricht.

# %%
2te_zahl = 8

# %%
name = "Mia"
print(Name)

# %%
text = "Bestanden: " + True

# %%
preis = float("3,75")

# %%
alter = input("Alter: ")
spaeter = alter + 10

# %%
zahl = input("Zahl: ")     # EINGABE: 4
print(zahl * 3)            # ERWARTET: 12

# %%
name = "Mia"
print("Hallo {name}!")      # ERWARTET: Hallo Mia!

# %% [markdown]
# <p style="page-break-after:always;"></p>
#
# ### Aufgabe 3 - Werte und Datentypen [1]
#
# Bestimme den Wert und den Datentyp der Variable ```ergebnis``` am Ende des Programms. Notiere deine Antwort direkt als Kommentar im Code-Block.

# %%
zahl = 5
zahl = zahl + 4
zahl = zahl ** 2
rest = zahl % 10
ergebnis = rest / 2

# %% [markdown]
# <p style="page-break-after:always;"></p>
#
# ### Aufgabe 4 - Werte und Datentypen [2]
#
# Bestimme den Wert und den Datentyp der Variable ```text``` am Ende des Programms. Notiere deine Antwort direkt als Kommentar im Code-Block.

# %%
text = '6'
zahl = int(text)
zahl = zahl * 2
text = text + str(zahl)
text = text * 2

# %% [markdown]
# <p style="page-break-after:always;"></p>
#
# ### Aufgabe 5 - Zeichengetreue Ausgabe
#
# Notiere zu jeder Zeile die genaue Ausgabe.
#
# Schreibe dies direkt mit Hilfe eines Kommentars hinter den Code.
#
# Nimm an das für die Variablen folgendes gilt: `name = 'Ada'` und `punkte = 18`.
#
# Achte auf Leerzeichen, Satzzeichen und Platzhalter.

# %%
print("Hallo", name, "!")
print(f"Hallo {name}!")
print("Punkte: " + str(punkte))
print("Punkte: {punkte}")
print(punkte / 3)
print(punkte // 3)
print(punkte % 5)

# %% [markdown]
# <p style="page-break-after:always;"></p>
#
# ### Aufgabe 6 - Schrittweise Implementierung
#
# Implementiere die folgenden Stichpunkte in genau der angegebenen Reihenfolge.
#
# * Lies eine Gleitkommazahl `a` ein.
# * Lies eine ganze Zahl `b` ein.
# * Berechne `a * b` und speichere das Ergebnis in einer Variable mit dem Namen `produkt`.
# * Berechne `a ** 2` und speichere das Ergebnis in einer Variable mit dem Namen `quadrat`.
# * Gib den Quotienten `produkt / quadrat` aus.
# * Gib in einer neuen Zeile genau den Text: „Weiter geht es!“ aus.
# * Gib die Datentypen von `produkt` und `quadrat` als Kommentare direkt im Code an.

# %%
# HIER IST PLATZ FÜR EURE LÖSUNG! :)

# %% [markdown]
# <p style="page-break-after:always;"></p>
#
# ### Aufgabe 7 - Problemlösung
#
# Apple hat die letzten Tage das iPhone Duo vorgestellt. In der absoluten Vollausstattung kostet dieses Gerät unglaubliche `3.799,00 €`.
#
# Implementiere ein Programm das den Nutzer oder die Nutzerin zuerst nach dem Namen und im Anschluss nach dem Stundenlohn fragt.
#
# Gib am Ende aus, wie viele Stunden diese Person arbeiten müsste, nur um sich dieses völlig überteurte Gerät leisten zu können.
#
# Bei der Ausgabe soll der Nutzer oder die Nutzerin mit Namen angesprochen werden.
#
# **Zur Einordnung und zum Testen**: Der aktuelle gesetzliche Mindestlohn in Deutschland liegt bei `13,90 €`.

# %%
# HIER IST PLATZ FÜR EURE LÖSUNG! :)

# %% [markdown]
# <p style="page-break-after:always;"></p>

# %% [markdown]
# <hr/>
#
# <div style="width:100%; text-align:center;">
# <p style="text-align:center; margin:0;">© Patrick Binkert & Dr. Stephan Matos Camacho | SJ 26 / 27</p>
# <br/>
# <img src="00_coding@BvC.png" alt="FooterImage" width="400" style="display:block; width:400px; max-width:100%; height:auto; margin:0 auto;"/>
# </div>
